# %%
1
x = 3 ----> floata çevirelim. Çevirdikten sonra beri tipinide yazdıralım.

y = 4.5 -----> integere çevirelim. Çevirdikten sonra beri tipinide yazdıralım.

z = "8" -----> integera çevirelim. Çevirdikten sonra beri tipinide yazdıralım.

a = "12" -----> floata çevirelim. Çevirdikten sonra beri tipinide yazdıralım.

b = "46.8" ------> integera çevirelim. Çevirdikten sonra beri tipinide yazdıralım.

# %%
x = 3
x =float(3)
print(x)
type(x)
# Out:
# 3.0
# float

# %%
y = 4.5
y = int(4.5)
print(y)
type(y)
# Out:
# 4
# int

# %%
z = "8"
z= int("5")
print(z)
type(z)
# Out:
# 5
# int

# %%
a = "12"
a = float("12")
print(a)
type(a)
# Out:
# 12.0
# float

# %%
b = "46.8" 
b1 = float("46.8")
c = int(b1)
print(c)
type(c)
# Out:
# 46
# int

# %%
2
İsimlerden oluşan üç değişkene yaş değerleri atanır. Belirlenen üç değişken birbiriyle karşılaştırma operatörleri 
ile karşılaştırılır. Bu karşılaştırmalara mantıksal operatörler de eklenir.

# %%
ali = 30
tülin = 42
burak = 19

print("ali ninyası 25 den büyük mü?", ali>25)
print(" tülin veya ali büyük mü?", tülin> burak or ali> burak)
print("ali en büyük mü?", ali> tülin and tülin> burak)
print("burak ali den küçük mü?", burak < ali)
print("tülin ile ali aynı yas mı?", tülin == ali)
# Out:
# ali ninyası 25 den büyük mü? True
#  tülin veya ali büyük mü? True
# ali en büyük mü? False
# burak ali den küçük mü? True
# tülin ile ali aynı yas mı? False

# %%
3
Kullanıcıdan iki değer girmesini istenir. Girilen değerlerin toplama, çıkarma, çarpma, bölme sonuçlarını yazdırılır.

# %%
number1 = int(input("Bir deger giriniz: "))
number2 = int(input('Bir deger giriniz: '))

# toplama
t= print( number1 + number2)
ci= print( number1 - number2)
ca= print( number1 * number2)
b= print( number1 / number2)
# Out:
# Bir deger giriniz:  5
# Bir deger giriniz:  25
# 30
# -20
# 125
# 0.2

# %%
4
Kullanıcıdan isim, yaş, şehir ve meslek bilgilerini istenir ve cevaplarını yazdırılır.

# %%
name=input("İsminizi Giriniz: ")
age = int(input(" Yaşınızı giriniz: "))
city = input("Şehrinizi yazınız: ")
job = input("Mesleginizi girin: ")
# Out:
# İsminizi Giriniz:  Gizem
#  Yaşınızı giriniz:  31
# Şehrinizi yazınız:  izmir
# Mesleginizi girin:  yazılımcı

# %%
5
# "Hi-Kod Veri Bilimi Atölyesi" ifadesini bir değişkene tanımlanır.

İfadedeki her bir kelimeyi ("Hi-Kod", "Veri", "Bilimi", "Atölyesi") değişken içinden seçilir.
İfadeyi hepsini büyük harf olacak hale çevrilir. ("HI-KOD VERİ BİLİMİ ATÖLYESİ")
İfadeyi hepsini büyük harf olacak hale çevrilir.("hi-kod veri bilimi atölyesi")
"0123456789" ifadesindeki yalnızca çift sayıları ve yalnızca tek sayıları seçilir. ("02468", "13579")

# %%
yapay_zeka =("Hi-Kod Veri Bilimi Atölyesi")
yapay_zeka.split()
# Out:
# ['Hi-Kod', 'Veri', 'Bilimi', 'Atölyesi']

# %%
yapay_zeka.upper()
# Out:
# 'HI-KOD VERI BILIMI ATÖLYESI'

# %%
yapay_zeka.lower()
# Out:
# 'hi-kod veri bilimi atölyesi'
