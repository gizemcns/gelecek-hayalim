# %% [markdown]
# <a href="https://colab.research.google.com/github/gizemcns/gelecek-hayalim/blob/main/KODLUYORUZ_ODEV5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ödev 1:

liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

# Aşağıdaki işlemleri indexing ve slicing kullanarak liste üzerinde uygulayın.

# "3" değerine ulaşmak için indexleme yapın.
# "Hi-Kod" değerine ulaşmak için indexleme yapın.
# 4.7 değerine ulaşmak için indexleme yapın.
# 9,"3",8.4,"Hi-Kod" değerlerine ulaşmak için slicing yapın.
# 8.4,"Hi-Kod","False",4.7 değerlerine ulaşmak için slicing yapın.

# %%
liste[3:4]
# Out:
# ['3']

# %%
liste[5]
# Out:
# 'Hi-Kod'

# %%
liste[-1]
# Out:
# 4.7

# %%
liste[2:6]
# Out:
# [9, '3', 8.4, 'Hi-Kod']

# %%
liste[4:8]
# Out:
# [8.4, 'Hi-Kod', 'False', 4.7]

# %%
# Ödev 2
# Verilen listede bulunan string veri tipindeki öğeleri yeni_liste isimli listeye eklenir.

liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

# %%
new_list = []

for i in liste:
  if type(i) == str:
    new_list.append(i)

print(new_list)
# Out:
# ['Python', '3', 'Hi-Kod', 'False']

# %%
# Ödev 3
# Enumerate methodunu araştırın ve aşağıdaki örneği enumerate methodu ile yapın.

meyveler= [ 'elma' ,'armut', 'kiraz', 'muz', 'mango', 'çilek']

for index in range(len(meyveler)):

    print("{}. indexte bulunan meyve: {}".format(index,meyveler[index]))

# %%
meyveler= [ 'elma' ,'armut', 'kiraz', 'muz', 'mango', 'çilek']

for index, value in enumerate(meyveler):

  print("{}. indexte bulunan meyve: {}".format(index,meyveler[index]))
# Out:
# 0. indexte bulunan meyve: elma
# 1. indexte bulunan meyve: armut
# 2. indexte bulunan meyve: kiraz
# 3. indexte bulunan meyve: muz
# 4. indexte bulunan meyve: mango
# 5. indexte bulunan meyve: çilek
