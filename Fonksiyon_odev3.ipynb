# %% [markdown]
# #### Ödev 1
# Kullanıcıdan pi değeri ve yarıçap bilgisi alarak dairenin alanını hesaplayan bir fonksiyon oluşturulur.

# %%
def dairenin_alani_hesapla(pi, yaricap):
    alan = pi* yaricap**2
    return  alan

pi = float(input('Pi sayısını giriniz : ') )
yaricap = float(input('Yarıçap bilgisi giriniz : ') )

alan = dairenin_alani_hesapla(pi, yaricap)
print(alan)
# Out:
# Pi sayısını giriniz :  3.14
# Yarıçap bilgisi giriniz :  2
# 12.56

# %% [markdown]
# #### Ödev 2
#
# Faktöriyel adında fonksiyon oluşturulur. Döngü kullanarak parametre olarak girilen sayının faktöriyeli hesaplanır. Format metodunu kullanılarak ekrana yazdırılır.

# %%
def factoriel(n):
    carpım = 1
    for i in range(1,n+1):
        carpım = carpım *i
    return carpım


print("Faktöriyel Sonucu: {}".format(factoriel(5)))
# Out:
# Faktöriyel Sonucu: 120

# %% [markdown]
# #### Ödev 3
# Kişinin fonksiyona doğum yılını vererek kaç yaşında olduğunu hesaplayan bir fonksiyon oluşturun.

# %%
from datetime import datetime


def kisinin_yasi(dogum_yili):
    simdiki_yil = datetime.now().year
    yas = simdiki_yil - dogum_yili
    return yas


dogum_yili = int(input('Dogum yılınızı giriniz: '))

print(f'Yaşınız: {kisinin_yasi(dogum_yili)}')
# Out:
# Dogum yılınızı giriniz:  1993
# Yaşınız: 32

# %% [markdown]
# #### Ödev 4
#
# Doğum yılı ve isim bilgisi verilen fonksiyon kişinin emekli olup olmadığını söylesin.(Kişi 65 yaşında ise emekli olur.) Burada yaş hesabını yukarıdaki örnekteki fonksiyonu kullanarak yapsın.(Yani fonksiyon içinde fonksiyon kullanmanızı istiyorum :)) Kişi 65 yaşında ya da daha fazlaysa "Emekli oldunuz" yanıtını, 65 yaşından küçükse emekliliğine kaç yıl kaldığını da hesaplayarak "(isim) emekliliğine (yıl) kaldı." yanıtını versin.

# %%
from datetime import datetime


def kisinin_yasi(dogum_yili):
    simdiki_yil = datetime.now().year
    yas = simdiki_yil - dogum_yili
    return yas


dogum_yili = int(input('Dogum yılınızı giriniz: '))
isim_soyisim = input('İsim ve soyisim giriniz: ')

yas = kisinin_yasi(dogum_yili)

print(f"Yaşınız: {kisinin_yasi(dogum_yili)}")

if yas >= 65:
        print('Emekli oldunuz')
else:
    emeklilik = 65 - yas
    print(f'{isim_soyisim} emekliliğine {emeklilik} yıl kalmıştır..!')
# Out:
# Dogum yılınızı giriniz:  1993
# İsim ve soyisim giriniz:  gizem
# Yaşınız: 32
# gizem emekliliğine 33 yıl kalmıştır..!
