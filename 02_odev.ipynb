# %%
Ödev-1: Kullanıcıdan maaş bilgisini istenir ve bu bilgiye göre maaşından ne kadar vergi kesileceğini hesaplanır. Kullanıcının geliri;

10000 ve altındaysa maaşından %5 kesinti olur.
25000 ve altındaysa maaşından %10 kesinti olur.
45000 ve altındaysa maaşından %25 kesinti olur.
Diğer koşullarda %30 kesinti olur.
Bu durumlara göre kullanıcının yeni maaşı yazdırılır.

# %%
maas_bilgisi = float(input('Maaşınızı giriniz: '))

if maas_bilgisi<=10000:
      vergi = maas_bilgisi * 0.05
      print(f'Net Maaşınız, {maas_bilgisi-vergi}')
elif maas_bilgisi<=25000:
      vergi = maas_bilgisi * 0.10
      print(f'Net Maaşınız, {maas_bilgisi-vergi}')
elif maas_bilgisi<=45000:
      vergi = maas_bilgisi * 0.25
      print(f'Net Maaşınız, {maas_bilgisi-vergi}')
else:
      vergi = maas_bilgisi * 0.30
      print(f'Net Maaşınız, {maas_bilgisi-vergi}')
# Out:
# Maaşınızı giriniz: 42000
# Net Maaşınız, 31500.0

# %%
Ödev-2: Kullanıcıdan kullanıcı adı ve şifre oluşturmasını istenir. Şifrenin uzunluğu altı haneye ulaşmışsa hesabınız oluşturuldu
mesajı alınır, altı haneden azsa altı haneli şifre oluşturması gerektiğinin mesajı alınır. (Sadece koşul kullanılması yeterli.)

# %%
user_name = input('Kullanıcı Adınızı Giriniz: ')
password = input('Şifrenizi Giriniz: ')

if len(password)==6:
  print('Hesabınız oluşturuldu')
elif len(password)<6:
  print('Altı haneli bir şifre giriniz...!!')
# Out:
# Kullanıcı Adınızı Giriniz: gizem
# Şifrenizi Giriniz: 123456
# Hesabınız oluşturuldu

# %%
Ödev-3: Bir önceki örnek geliştirilir.

Kullanıcı girdiği şifre 5 ve 10 hane arasında olmak zorunda.
Eğer bu koşula uyuyorsa "Hesabınız oluşturuldu." mesajı alır.
Koşulu sağlamıyorsa "Lütfen girdiniz şifre 5 haneden az 10 haneden fazla olmasın!" uyarısı alır.
Bunu oluştururken kullanıcı istediğimiz şartlarda şifre oluşturana kadar sormaya devam eder

# %%
while True:
  user_name = input('Kullanıcı Adınızı Giriniz: ')
  password = input('Şifrenizi Giriniz: ')

  if 5<len(password)<10:
    print('Hesabınız oluşturuldu')
    break
  else:
    print('Lütfen girdiğiniz şifre 5 haneden az 10 haneden fazla olmasın!!')
# Out:
# Kullanıcı Adınızı Giriniz: gizem
# Şifrenizi Giriniz: 123
# Lütfen girdiğiniz şifre 5 haneden az 10 haneden fazla olmasın!!
# Kullanıcı Adınızı Giriniz: gizem
# Şifrenizi Giriniz: 12365
# Lütfen girdiğiniz şifre 5 haneden az 10 haneden fazla olmasın!!
# Kullanıcı Adınızı Giriniz: gizem
# Şifrenizi Giriniz: 12345678968541
# Lütfen girdiğiniz şifre 5 haneden az 10 haneden fazla olmasın!!
# Kullanıcı Adınızı Giriniz: gzem
# Şifrenizi Giriniz: 12345678910
# Lütfen girdiğiniz şifre 5 haneden az 10 haneden fazla olmasın!!
# Kullanıcı Adınızı Giriniz: 1234569
# Şifrenizi Giriniz: 123456
# Hesabınız oluşturuldu

# %%
Ödev-4: Kullanıcıdan isim ve şifre isteyeceğiz ve şifre girişi için üç hak verilir.

Eğer önceden tanımlı şifre ile kullanıcıdan gelen şifre aynıysa "Giriş yapıldı." yazar.
Şifre girişi yanlışsa "Yanlış şifre girildi!" uyarısı verilsin ve üç yanlış denemede program biter.
Tercihe göre kalan hak bilgisi verilir.

# %%
user_name = input('Kullanıcı Adınızı Giriniz: ')


user_name1 ='Gizem'
password = '123456'
giris_hakkı = 3

while giris_hakkı >0:
  password1 = input('Şifrenizi Giriniz: ')

  if password==password1:
    print('Hesabınıza Giriş Yapıldı')
    break

  else:
    giris_hakkı -=1

    print("Yanlış Şifre Girildi..!")

  if giris_hakkı> 0:

    print(f"Kalan Hakkınız: , {giris_hakkı} ")

if giris_hakkı == 0:

  print('3 hakkınız dolmuştur, program kapandı..!')
# Out:
# Kullanıcı Adınızı Giriniz: gizem
# Şifrenizi Giriniz: 12
# Yanlış Şifre Girildi..!
# Kalan Hakkınız: , 2
# Şifrenizi Giriniz: 123456
# Hesabınıza Giriş Yapıldı
